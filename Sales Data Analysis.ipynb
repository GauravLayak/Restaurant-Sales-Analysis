# %% [markdown]
# # Sales Data Analysis Using Python

# %% [markdown]
# # Restraurant Sales Dataset

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Since our dataset is in xlsx format so we use pd.read_excel()
data = pd.read_excel('/content/drive/MyDrive/datasets/Sales-Data-Analysis.xlsx')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 250         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 251         NaN      10710  2022-12-29 00:00:00             Burgers
# 252         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 253         NaN      10712  2022-12-29 00:00:00               Fries
# 254         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %% [markdown]
# # Drop Unwanted Columns

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data
# Out:
#     Unnamed: 1           Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0     Order ID                 Date             Product      Price
# 1        10452  2022-11-07 00:00:00               Fries       3.49
# 2        10453  2022-11-07 00:00:00           Beverages       2.95
# 3        10454  2022-11-07 00:00:00       Sides & Other       4.99
# 4        10455  2022-11-08 00:00:00             Burgers      12.99
# ..         ...                  ...                 ...        ...
# 250      10709  2022-12-28 00:00:00       Sides & Other       4.99
# 251      10710  2022-12-29 00:00:00             Burgers      12.99
# 252      10711  2022-12-29 00:00:00  Chicken Sandwiches       9.95
# 253      10712  2022-12-29 00:00:00               Fries       3.49
# 254      10713  2022-12-29 00:00:00           Beverages       2.95
#
#      Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0      Quantity  Purchase Type  Payment Method             Manager       City
# ...

# %% [markdown]
# # Changing the columns names

# %%
data.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data.columns = data.loc[0]

# %%
data.head()
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 0  Order ID                 Date        Product  Price    Quantity
# 1     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00      Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00  Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00        Burgers  12.99  569.668976
#
# 0  Purchase Type  Payment Method             Manager    City
# 0  Purchase Type  Payment Method             Manager    City
# 1        Online        Gift Card    Tom      Jackson  London
# 2        Online        Gift Card         Pablo Perez  Madrid
# 3      In-store        Gift Card       Joao    Silva  Lisbon
# 4      In-store      Credit Card       Walter Muller  Berlin

# %% [markdown]
# # Drop Unwanted 1st Row

# %%
data.drop(0, inplace= True)

# %%
data.head()
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card    Tom      Jackson  London
# 2       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store       Gift Card       Joao    Silva  Lisbon
# 4     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Walter Muller  Berlin

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %% [markdown]
# # Consider Manager Column

# %%
data['Manager']
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
# in manager columns, there are extra spaces between words

# find unique values
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
# find number of unique values
data.Manager.nunique()
# Out:
# 14

# %%
# remove extra spaces
data['Manager'] = data.Manager.str.strip().str.replace(r'\s+', ' ', regex= True)

# %%
# check
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.head(10)
# Out:
# 0  Order ID                 Date             Product  Price    Quantity  \
# 1     10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5     10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6     10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7     10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 8     10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 9     10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 10    10462  2022-11-09 00:00:00               Fries   3.49  573.065903
#
# 0  Purchase Type Payment Method        Manager    City
# 1        Online       Gift Card    Tom Jackson  London
# 2        Online       Gift Card    Pablo Perez  Madrid
# ...

# %% [markdown]
# # Removing Duplicates Records

# %%
data.describe()
# Out:
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %%
# show all duplicate records
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
# there is no duplicate records

# but to remove the duplicate records if any
data.drop_duplicates(inplace=True)

# %%
# to check
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
# to check any duplicates manually

# check count and unique rows values
data.describe()
# Out:
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %% [markdown]
# # Converting datatypes of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
# columns - Quantity and Prices should be in Integer data-types

data['Quantity'] = data['Quantity'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 18.0+ KB

# %%
# Roundoff the values
data['Quantity'] = data['Quantity'].round()

# %%
data.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 250    200.0
# 251    754.0
# 252    281.0
# 253    630.0
# 254    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
# to remove the 0

# we convert this column into integer datatypes
data['Quantity'] = data['Quantity'].astype(int)

# %%
# to check
data.Quantity
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    678
# Name: Quantity, Length: 254, dtype: int64

# %%
# Now  with Order ID Column
data['Order ID'] = data['Order ID'].astype(int)

# Price column
data['Price'] = data['Price'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 18.0+ KB

# %%
# to convert date column datatype
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 18.0+ KB

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# ...

# %% [markdown]
# # Analysing the Data

# %% [markdown]
# 1. Most Prefered Payment Method?

# %%
# find unique values in payment column
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
# how many uniques values in payment column
data['Payment Method'].nunique()
# Out:
# 3

# %%
# find counts of each unique values
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
# in percentage form
data['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
# Plot bargraph
data['Payment Method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %% [markdown]
# Insights: Credit Card is most prefered method, followed by Cash

# %% [markdown]
# 2. Most Selling product? (by Quantity, and by Revenue)

# %%
# by quantity

data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
# Plot bargraph

# 1st we assign it
most_quantity = data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)

# %%
# 2nd we convert it into dataframe
most_quantity= most_quantity.reset_index()

# %%
# to check
most_quantity
# Out:
#               Product  Quantity
# 0           Beverages     34988
# 1               Fries     32023
# 2             Burgers     29018
# 3  Chicken Sandwiches     11133
# 4       Sides & Other      9800

# %%
# 3rd we plot
plt.figure(figsize=(9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'], color= ['red', 'blue', 'green', 'yellow', 'violet'])
plt.title('Most Selling Product - By Quantity')
plt.xlabel('Product')
plt.ylabel('Quantity')
plt.show()

# %%
# By Revenue

# create a new column
data['Revenue'] = data['Quantity'] * data['Price']

# %%
# check
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
# groupby
data.groupby('Product')['Revenue'].sum().sort_values(ascending= False)
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
# assign it
most_revenue = data.groupby('Product')['Revenue'].sum().sort_values(ascending= False)

# %%
# to check
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
# convert it into dataframe
most_revenue= most_revenue.reset_index()

# %%
# check
most_revenue
# Out:
#               Product    Revenue
# 0             Burgers  376943.82
# 1               Fries  125626.57
# 2  Chicken Sandwiches  114612.45
# 3           Beverages  103214.60
# 4       Sides & Other   48902.00

# %%
# plot bargraph
plt.figure(figsize=(9,4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'], color= ['red', 'blue', 'green', 'yellow', 'violet'])
plt.title('Most Selling Product - By Revenue')
plt.xlabel('Product')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# 3. Which city had max revenue or Which manager earned max revenue

# %%
# find unique cities
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
# count of unique cities
data.City.nunique()
# Out:
# 5

# %%
# groupby
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    241635.49
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %%
# for Manager part

# unique managers
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
# counts of unique managers
data.Manager.nunique()
# Out:
# 5

# %%
# groupby
data.groupby('Manager')['Revenue'].sum().sort_values(ascending= False)
# Out:
# Manager
# Joao Silva       241635.49
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# 4. Date Wise revenue

# %%
data.plot('Date', 'Revenue', color = 'green', linewidth= 2, figsize=(9,4))
plt.title("Date Wise Revenue")
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# 5. Average Revenue

# %%
data['Revenue'].mean()
# Out:
# np.float64(3028.737952755905)

# %% [markdown]
# 6. Average Revenue of November and December Month

# %%
# Create a new column
data['Month'] = data['Date'].dt.month

# %%
# to check
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
# to check the November month
m11 = data[data['Month'] == 11]

# %%
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 109     10568 2022-11-30           Beverages   2.95       678       Online
# 110     10569 2022-11-30       Sides & Other   4.99       200       Online
# 128     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129     10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
# Average revenue of November
m11['Revenue'].mean()
# Out:
# np.float64(2938.1869026548666)

# %%
# for december month
m12 = data[data['Month'] == 12]

# %%
# Average Revenue of December
m12['Revenue'].mean()
# Out:
# np.float64(3101.3072340425533)

# %% [markdown]
# 7. Standard Deviation of Revenue and Quantity

# %%
data['Quantity'].std()
# Out:
# 214.97943096363838

# %%
data['Revenue'].std()
# Out:
# 2419.9325462715055

# %% [markdown]
# 8. Variance of Revenue and Quantity

# %%
data['Quantity'].var()
# Out:
# 46216.155737449764

# %%
data['Revenue'].var()
# Out:
# 5856073.528504092

# %% [markdown]
# 9. Is revenue increasing or decreasing over time

# %%
# check total revenue of november and december month
m11['Revenue'].sum()
# Out:
# np.float64(332015.11999999994)

# %%
m12['Revenue'].sum()
# Out:
# np.float64(437284.32)

# %% [markdown]
# Insights: Yes, Revenue is increasing over time

# %% [markdown]
# 10. Average 'Quantity Sold' and 'Average Revenue' for each product

# %%
# groupby
data.groupby('Product')[['Quantity', 'Revenue']].agg({'Quantity': 'mean', 'Revenue': 'mean'})
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           699.760000  2064.292000
# Burgers             558.038462  7248.919615
# Chicken Sandwiches  214.096154  2204.085577
# Fries               627.901961  2463.266078
# Sides & Other       200.000000   998.000000
